# %% [markdown]
# # Thrones2Vec

# %% [markdown]
# © Yuriy Guts, 2016

# %% [markdown]
# Using only the raw text of [A Song of Ice and Fire](https://en.wikipedia.org/wiki/A_Song_of_Ice_and_Fire), we'll derive and explore the semantic properties of its words.

# %% [markdown]
# ## Imports

# %%
from __future__ import absolute_import, division, print_function

# %%
import codecs
import glob
import logging
import multiprocessing
import os
import pprint
import re

# %%
import nltk
from gensim.models import word2vec as w2v
import sklearn.manifold
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# **Set up logging**

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# **Download NLTK tokenizer models (only the first time)**

# %%
nltk.download("punkt")
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt to /home/tarun/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/tarun/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# ## Prepare Corpus

# %% [markdown]
# **Load books from files**

# %%
book_filenames = sorted(glob.glob("data/*.txt"))

# %%
print("Found books:")
book_filenames
# Out:
# Found books:
# ['data/got1.txt',
#  'data/got2.txt',
#  'data/got3.txt',
#  'data/got4.txt',
#  'data/got5.txt']

# %% [markdown]
# **Combine the books into one string**

# %%
corpus_raw = u""
for book_filename in book_filenames:
    print("Reading '{0}'...".format(book_filename))
    with codecs.open(book_filename, "r", "utf-8") as book_file:
        corpus_raw += book_file.read()
    print("Corpus is now {0} characters long".format(len(corpus_raw)))
    print()
# Out:
# Reading 'data/got1.txt'...
# Corpus is now 1770659 characters long
#
# Reading 'data/got2.txt'...
# Corpus is now 4071041 characters long
#
# Reading 'data/got3.txt'...
# Corpus is now 6391405 characters long
#
# Reading 'data/got4.txt'...
# Corpus is now 8107945 characters long
#
# Reading 'data/got5.txt'...
# Corpus is now 9719485 characters long

# %% [markdown]
# **Split the corpus into sentences**

# %%
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
raw_sentences = tokenizer.tokenize(corpus_raw)

# %%
#convert into a list of words
#rtemove unnnecessary,, split into words, no hyphens
#list of words
def sentence_to_wordlist(raw):
    clean = re.sub("[^a-zA-Z]"," ", raw)
    words = clean.split()
    return words

# %%
#sentence where each word is tokenized
sentences = []
for raw_sentence in raw_sentences:
    if len(raw_sentence) > 0:
        sentences.append(sentence_to_wordlist(raw_sentence))

# %%
print(raw_sentences[5])
print(sentence_to_wordlist(raw_sentences[5]))
# Out:
# Heraldic crest by Virginia Norey.
# ['Heraldic', 'crest', 'by', 'Virginia', 'Norey']

# %%
token_count = sum([len(sentence) for sentence in sentences])
print("The book corpus contains {0:,} tokens".format(token_count))
# Out:
# The book corpus contains 1,818,103 tokens

# %% [markdown]
# ## Train Word2Vec

# %%
#ONCE we have vectors
#step 3 - build model
#3 main tasks that vectors help with
#DISTANCE, SIMILARITY, RANKING

# Dimensionality of the resulting word vectors.
#more dimensions, more computationally expensive to train
#but also more accurate
#more dimensions = more generalized
num_features = 300
# Minimum word count threshold.
min_word_count = 3

# Number of threads to run in parallel.
#more workers, faster we train
num_workers = multiprocessing.cpu_count()

# Context window length.
context_size = 7

# Downsample setting for frequent words.
#0 - 1e-5 is good for this
downsampling = 1e-3

# Seed for the RNG, to make the results reproducible.
#random number generator
#deterministic, good for debugging
seed = 1

# %%
thrones2vec = w2v.Word2Vec(
    sg=1,
    seed=seed,
    workers=num_workers,
    size=num_features,
    min_count=min_word_count,
    window=context_size,
    sample=downsampling
)

# %%
thrones2vec.build_vocab(sentences)
# Out:
# 2018-07-13 13:32:13,420 : INFO : collecting all words and their counts
# 2018-07-13 13:32:13,421 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-07-13 13:32:13,486 : INFO : PROGRESS: at sentence #10000, processed 140984 words, keeping 10280 word types
# 2018-07-13 13:32:13,527 : INFO : PROGRESS: at sentence #20000, processed 279730 words, keeping 13558 word types
# 2018-07-13 13:32:13,582 : INFO : PROGRESS: at sentence #30000, processed 420336 words, keeping 16598 word types
# 2018-07-13 13:32:13,640 : INFO : PROGRESS: at sentence #40000, processed 556581 words, keeping 18324 word types
# 2018-07-13 13:32:13,679 : INFO : PROGRESS: at sentence #50000, processed 686247 words, keeping 19714 word types
# 2018-07-13 13:32:13,728 : INFO : PROGRESS: at sentence #60000, processed 828497 words, keeping 21672 word types
# 2018-07-13 13:32:13,790 : INFO : PROGRESS: at sentence #70000, processed 973830 words, keeping 23093 word types
# 2018-07-13 13:32:13,862 : INFO : PROGRESS: at sentence #80000, processed 1114967 words, keeping 24252 word types
# 2018-07-13 13:32:13,933 : INFO : PROGRESS: at sentence #90000, processed 1260481 words, keeping 26007 word types
# 2018-07-13 13:32:13,988 : INFO : PROGRESS: at sentence #100000, processed 1393203 words, keeping 26884 word types
# 2018-07-13 13:32:14,043 : INFO : PROGRESS: at sentence #110000, processed 1532150 words, keeping 27809 word types
# 2018-07-13 13:32:14,113 : INFO : PROGRESS: at sentence #120000, processed 1680961 words, keeping 28486 word types
# 2018-07-13 13:32:14,159 : INFO : collected 29026 word types from a corpus of 1818103 raw words and 128868 sentences
# 2018-07-13 13:32:14,159 : INFO : Loading a fresh vocabulary
# 2018-07-13 13:32:14,229 : INFO : effective_min_count=3 retains 17277 unique words (59% of original 29026, drops 11749)
# 2018-07-13 13:32:14,241 : INFO : effective_min_count=3 leaves 1802699 word corpus (99% of original 1818103, drops 15404)
# 2018-07-13 13:32:14,331 : INFO : deleting the raw counts dictionary of 29026 items
# 2018-07-13 13:32:14,333 : INFO : sample=0.001 downsamples 50 most-common words
# 2018-07-13 13:32:14,334 : INFO : downsampling leaves estimated 1404424 word corpus (77.9% of prior 1802699)
# 2018-07-13 13:32:14,421 : INFO : estimated required memory for 17277 words and 300 dimensions: 50103300 bytes
# 2018-07-13 13:32:14,422 : INFO : resetting layer weights

# %%
print("Word2Vec vocabulary length:", len(thrones2vec.wv.vocab))
# Out:
# Word2Vec vocabulary length: 17277

# %% [markdown]
# **Start training, this might take a minute or two...**

# %%
thrones2vec.train(sentences,total_examples=thrones2vec.corpus_count,epochs=5)
# 2018-07-13 13:36:54,031 : INFO : EPOCH 4 - PROGRESS: at 71.52% examples, 136188 words/s, in_qsize 7, out_qsize 0
# 2018-07-13 13:36:55,086 : INFO : EPOCH 4 - PROGRESS: at 84.04% examples, 138382 words/s, in_qsize 7, out_qsize 0
# 2018-07-13 13:36:56,189 : INFO : EPOCH 4 - PROGRESS: at 93.98% examples, 138467 words/s, in_qsize 7, out_qsize 0
# 2018-07-13 13:36:56,668 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-07-13 13:36:56,670 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-07-13 13:36:56,694 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-07-13 13:36:56,776 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-07-13 13:36:56,777 : INFO : EPOCH - 4 : training on 1818103 raw words (1403356 effective words) took 10.1s, 139612 effective words/s
# 2018-07-13 13:36:57,855 : INFO : EPOCH 5 - PROGRESS: at 9.27% examples, 122656 words/s, in_qsize 7, out_qsize 0
# 2018-07-13 13:36:58,864 : INFO : EPOCH 5 - PROGRESS: at 20.37% examples, 137158 words/s, in_qsize 7, out_qsize 0
# 2018-07-13 13:36:59,890 : INFO : EPOCH 5 - PROGRESS: at 31.78% examples, 141745 words/s, in_qsize 7, out_qsize 0
# 2018-07-13 13:37:00,890 : INFO : EPOCH 5 - PROGRESS: at 43.42% examples, 144867 words/s, in_qsize 7, out_qsize 0
# 2018-07-13 13:37:01,993 : INFO : EPOCH 5 - PROGRESS: at 54.05% examples, 143873 words/s, in_qsize 7, out_qsize 0
# 2018-07-13 13:37:02,996 : INFO : EPOCH 5 - PROGRESS: at 62.25% examples, 139353 words/s, in_qsize 7, out_qsize 0
# 2018-07-13 13:37:04,042 : INFO : EPOCH 5 - PROGRESS: at 71.52% examples, 137242 words/s, in_qsize 8, out_qsize 0
# 2018-07-13 13:37:05,080 : INFO : EPOCH 5 - PROGRESS: at 83.49% examples, 138673 words/s, in_qsize 7, out_qsize 0
# 2018-07-13 13:37:06,109 : INFO : EPOCH 5 - PROGRESS: at 93.43% examples, 139814 words/s, in_qsize 7, out_qsize 0
# 2018-07-13 13:37:06,641 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-07-13 13:37:06,793 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-07-13 13:37:06,832 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-07-13 13:37:06,842 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-07-13 13:37:06,843 : INFO : EPOCH - 5 : training on 1818103 raw words (1404261 effective words) took 10.1s, 139619 effective words/s
# 2018-07-13 13:37:06,845 : INFO : training on a 9090515 raw words (7021300 effective words) took 50.9s, 138000 effective words/s
# (7021300, 9090515)

# %% [markdown]
# **Save to file, can be useful later**

# %%
if not os.path.exists("trained"):
    os.makedirs("trained")

# %%
thrones2vec.save(os.path.join("trained", "thrones2vec.w2v"))
# Out:
# 2018-07-13 13:37:12,989 : INFO : saving Word2Vec object under trained/thrones2vec.w2v, separately None
# 2018-07-13 13:37:12,992 : INFO : not storing attribute vectors_norm
# 2018-07-13 13:37:12,994 : INFO : not storing attribute cum_table
# 2018-07-13 13:37:13,759 : INFO : saved trained/thrones2vec.w2v

# %% [markdown]
# ## Explore the trained model.

# %%
thrones2vec = w2v.Word2Vec.load(os.path.join("trained", "thrones2vec.w2v"))
# Out:
# 2018-07-13 13:37:16,233 : INFO : loading Word2Vec object from trained/thrones2vec.w2v
# 2018-07-13 13:37:16,809 : INFO : loading vocabulary recursively from trained/thrones2vec.w2v.vocabulary.* with mmap=None
# 2018-07-13 13:37:16,811 : INFO : loading wv recursively from trained/thrones2vec.w2v.wv.* with mmap=None
# 2018-07-13 13:37:16,812 : INFO : setting ignored attribute vectors_norm to None
# 2018-07-13 13:37:16,813 : INFO : loading trainables recursively from trained/thrones2vec.w2v.trainables.* with mmap=None
# 2018-07-13 13:37:16,813 : INFO : setting ignored attribute cum_table to None
# 2018-07-13 13:37:16,816 : INFO : loaded trained/thrones2vec.w2v

# %% [markdown]
# ### Compress the word vectors into 2D space and plot them

# %%
#my video - how to visualize a dataset easily
tsne = sklearn.manifold.TSNE(n_components=2, random_state=0)

# %%
all_word_vectors_matrix = thrones2vec.wv.syn0
# Out:
# /home/tarun/.virtualenvs/thrones2vec/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.wv.vectors instead).
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# **Train t-SNE, this could take a minute or two...**

# %%
all_word_vectors_matrix_2d = tsne.fit_transform(all_word_vectors_matrix)

# %% [markdown]
# **Plot the big picture**

# %%
points = pd.DataFrame(
    [
        (word, coords[0], coords[1])
        for word, coords in [
            (word, all_word_vectors_matrix_2d[thrones2vec.wv.vocab[word].index])
            for word in thrones2vec.wv.vocab
        ]
    ],
    columns=["word", "x", "y"]
)

# %%
points.head(10)
# Out:
#        word         x         y
# 0    copper  1.711683  4.180491
# 1   reining -2.892559  3.371208
# 2     sires -1.728181 -0.487265
# 3   obscure -3.103142  3.511527
# 4  cramping  3.691626  2.650763
# 5   squalor  1.490457 -0.274510
# 6    Hother -2.245570 -1.725812
# 7  drooping  2.949649  2.974292
# 8       MAN  3.499072  4.577326
# 9      ants  2.804975 -0.848547

# %%
sns.set_context("poster")

# %%
points.plot.scatter("x", "y", s=10, figsize=(20, 12))

# %% [markdown]
# **Zoom in to some interesting places**

# %%
def plot_region(x_bounds, y_bounds):
    slice = points[
        (x_bounds[0] <= points.x) &
        (points.x <= x_bounds[1]) & 
        (y_bounds[0] <= points.y) &
        (points.y <= y_bounds[1])
    ]
    
    ax = slice.plot.scatter("x", "y", s=35, figsize=(10, 8))
    for i, point in slice.iterrows():
        ax.text(point.x + 0.005, point.y + 0.005, point.word, fontsize=11)

# %% [markdown]
# **People related to Kingsguard ended up together**

# %%
plot_region(x_bounds=(4.0, 4.2), y_bounds=(-0.5, -0.1))

# %% [markdown]
# **Food products are grouped nicely as well. Aerys (The Mad King) being close to "roasted" also looks sadly correct**

# %%
plot_region(x_bounds=(0, 1), y_bounds=(4, 4.5))

# %% [markdown]
# ### Explore semantic similarities between book characters

# %% [markdown]
# **Words closest to the given word**

# %%
thrones2vec.most_similar("Stark")
# Out:
# /home/tarun/.virtualenvs/thrones2vec/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# /home/tarun/.virtualenvs/thrones2vec/lib/python3.5/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('Eddard', 0.7566223740577698),
#  ('Winterfell', 0.6520140171051025),
#  ('Robb', 0.627800464630127),
#  ('beheaded', 0.6272307634353638),
#  ('Karstark', 0.6212029457092285),
#  ('Lyanna', 0.6186250448226929),
#  ('executed', 0.6158340573310852),
#  ('Benjen', 0.6057625412940979),
#  ('Rickard', 0.6030511856079102),
#  ('Brandon', 0.5988284349441528)]

# %%
thrones2vec.most_similar("Aerys")
# Out:
# /home/tarun/.virtualenvs/thrones2vec/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# /home/tarun/.virtualenvs/thrones2vec/lib/python3.5/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('Jaehaerys', 0.7851927280426025),
#  ('Daeron', 0.7758883237838745),
#  ('Mad', 0.7705341577529907),
#  ('appointment', 0.7288635969161987),
#  ('Rhaegar', 0.728487491607666),
#  ('reign', 0.7268516421318054),
#  ('Elia', 0.7145776152610779),
#  ('Maekar', 0.7126507759094238),
#  ('Unworthy', 0.7064024209976196),
#  ('II', 0.7043014764785767)]

# %%
thrones2vec.most_similar("direwolf")
# Out:
# /home/tarun/.virtualenvs/thrones2vec/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# /home/tarun/.virtualenvs/thrones2vec/lib/python3.5/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('wolf', 0.7206352949142456),
#  ('Rickon', 0.6929672956466675),
#  ('Ghost', 0.649745523929596),
#  ('pup', 0.6466563940048218),
#  ('SHAGGYDOG', 0.6451898813247681),
#  ('GHOST', 0.6278045773506165),
#  ('Reed', 0.6067428588867188),
#  ('eagle', 0.6027336120605469),
#  ('crannogman', 0.6022553443908691),
#  ('wight', 0.5963310599327087)]

# %% [markdown]
# **Linear relationships between word pairs**

# %%
def nearest_similarity_cosmul(start1, end1, end2):
    similarities = thrones2vec.most_similar_cosmul(
        positive=[end2, start1],
        negative=[end1]
    )
    start2 = similarities[0][0]
    print("{start1} is related to {end1}, as {start2} is related to {end2}".format(**locals()))
    return start2

# %%
nearest_similarity_cosmul("Stark", "Winterfell", "Riverrun")
nearest_similarity_cosmul("Jaime", "sword", "wine")
nearest_similarity_cosmul("Arya", "Nymeria", "dragons")
# Out:
# Stark is related to Winterfell, as Tully is related to Riverrun
# Jaime is related to sword, as drank is related to wine
# Arya is related to Nymeria, as Dany is related to dragons
# /home/tarun/.virtualenvs/thrones2vec/lib/python3.5/site-packages/ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `most_similar_cosmul` (Method will be removed in 4.0.0, use self.wv.most_similar_cosmul() instead).
#   after removing the cwd from sys.path.
# 'Dany'
